# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
dataHP = pd.read_csv("train_HP.csv")
dataHP.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
dataHP['LotFrontage'].isnull().mean()
# Out:
# 0.1773972602739726

# %%
col_con_nan = []

for col in dataHP.columns:
       porcentaje_faltante = dataHP[col].isnull().mean()
       if(porcentaje_faltante > 0):
              col_con_nan.append(col)

col_con_nan
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
dataHP[col_con_nan].isnull().mean()
# Out:
# LotFrontage     0.177397
# Alley           0.937671
# MasVnrType      0.597260
# MasVnrArea      0.005479
# BsmtQual        0.025342
# BsmtCond        0.025342
# BsmtExposure    0.026027
# BsmtFinType1    0.025342
# BsmtFinType2    0.026027
# Electrical      0.000685
# FireplaceQu     0.472603
# GarageType      0.055479
# GarageYrBlt     0.055479
# GarageFinish    0.055479
# GarageQual      0.055479
# GarageCond      0.055479
# PoolQC          0.995205
# Fence           0.807534
# MiscFeature     0.963014
# dtype: float64

# %% [markdown]
# #### 2. Efecto del CCA - Complete Case Analysis

# %%
cols_for_cca = [col for col in dataHP.columns if dataHP[col].isnull().mean() < 0.06]
cols_for_cca
# Out:
# ['Id',
#  'MSSubClass',
#  'MSZoning',
#  'LotArea',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageCars',
#  'GarageArea',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SaleType',
#  'SaleCondition',
#  'SalePrice']

# %%
dataHP_cca = dataHP[cols_for_cca].dropna()
dataHP.shape, dataHP_cca.shape
# Out:
# ((1460, 81), (1338, 74))

# %%
fig = plt.figure(figsize=(5, 3))
ax = fig.add_subplot(111)

dataHP['GrLivArea'].hist(bins=50, ax=ax, density=True, color='red', alpha=0.3)
dataHP_cca['GrLivArea'].hist(bins=50, ax=ax, density=True, color='blue', alpha=0.3)
plt.show()

# %% [markdown]
# #### Imputación por Media y Mediana

# %%
dataT = pd.read_csv("titanic.csv", usecols=['Age', 'Fare', 'Survived'])
dataT.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
dataT['Age'].isnull().mean()
# Out:
# 0.19865319865319866

# %%
media = dataT['Age'].mean()
mediana = dataT['Age'].median()

print(f"Media: {media} y Mediana: {mediana}")
# Out:
# Media: 29.69911764705882 y Mediana: 28.0

# %%
# imputación de datos
dataT['Age_Mean'] = np.round(dataT['Age'].fillna(media), 0 )
dataT['Age_Median'] = dataT['Age'].fillna(mediana)

# %%
fig = plt.figure(figsize=(5, 3))
ax = fig.add_subplot(111)

dataT['Age'].plot.density(color='red', legend='Original')
dataT['Age_Mean'].plot.density(color='blue', legend='Imput Media')
dataT['Age_Median'].plot.density(color='green', legend='Imput Mediana')
ax.legend()
plt.show()

# %%
print("Varianza Original", dataT['Age'].var())
print("Varianza Media", dataT['Age_Mean'].var())
print("Varianza Median", dataT['Age_Median'].var())
# Out:
# Varianza Original 211.0191247463081
# Varianza Media 169.02154125524902
# Varianza Median 169.51249827942328

# %% [markdown]
# ### Imputación de Variables Categóricas

# %%
dataHP.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
dataHP['SaleCondition'].unique()
# Out:
# array(['Normal', 'Abnorml', 'Partial', 'AdjLand', 'Alloca', 'Family'],
#       dtype=object)

# %% [markdown]
# #### Extraemos columnas con datos categóricos

# %%
categoricas = []

for col in dataHP.columns:
       tipo = dataHP[col].dtype
       if(tipo == 'object'):
              categoricas.append(col)

# %%
categoricas = [col for col in dataHP.columns if dataHP[col].dtype == 'object']
categoricas
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
categoricas
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
dataCat = dataHP[['BsmtQual', 'FireplaceQu', 'SalePrice']]
dataCat.head()
# Out:
#   BsmtQual FireplaceQu  SalePrice
# 0       Gd         NaN     208500
# 1       Gd          TA     181500
# 2       Gd          TA     223500
# 3       TA          Gd     140000
# 4       Gd          TA     250000

# %%
dataCat.isnull().mean()
# Out:
# BsmtQual       0.025342
# FireplaceQu    0.472603
# SalePrice      0.000000
# dtype: float64

# %%
dataCat['BsmtQual'].value_counts(normalize=True)
# Out:
# BsmtQual
# TA    0.456079
# Gd    0.434294
# Ex    0.085032
# Fa    0.024596
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(6, 3))
dataCat['BsmtQual'].value_counts(normalize=True).sort_values(ascending=False).plot.bar()
plt.xlabel("Categoria")
plt.ylabel("Cantidad de Casas")
plt.show()

# %%
fig = plt.figure(figsize=(6, 3))
ax = fig.add_subplot(111)
dataCat[dataCat['BsmtQual'] == 'Gd' ]['SalePrice'].plot(kind='kde', ax=ax, label='Gd')
dataCat[dataCat['BsmtQual'] == 'Ex' ]['SalePrice'].plot(kind='kde', ax=ax, label='Ex')
dataCat[dataCat['BsmtQual'] == 'Fa' ]['SalePrice'].plot(kind='kde', ax=ax, label='Fa')
dataCat[dataCat['BsmtQual'] == 'TA' ]['SalePrice'].plot(kind='kde', ax=ax, label='TA')
dataCat[dataCat['BsmtQual'].isnull()]['SalePrice'].plot(kind='kde', ax=ax, label='NAN')

plt.legend()
plt.show()

# %% [markdown]
# Dada la naturaleza estdística del conjunto de datos faltantes, es adecuado imputar la categoría 'Fa'.

# %%
dataHP['BsmtQual'].fillna('Fa', inplace=True)

# %% [markdown]
# ### Análisis para columna FireplaceQu

# %%
plt.figure(figsize=(6, 3))
dataCat['FireplaceQu'].value_counts(normalize=True).sort_values(ascending=False).plot.bar()
plt.xlabel("Categoria")
plt.ylabel("Cantidad de Casas")
plt.show()

# %%
fig = plt.figure(figsize=(6, 3))
ax = fig.add_subplot(111)
dataCat[dataCat['FireplaceQu'] == 'Gd' ]['SalePrice'].plot(kind='kde', ax=ax, label='Gd')
#dataCat[dataCat['FireplaceQu'] == 'Ex' ]['SalePrice'].plot(kind='kde', ax=ax, label='Ex')
#dataCat[dataCat['FireplaceQu'] == 'Fa' ]['SalePrice'].plot(kind='kde', ax=ax, label='Fa')
#dataCat[dataCat['FireplaceQu'] == 'TA' ]['SalePrice'].plot(kind='kde', ax=ax, label='TA')
#dataCat[dataCat['FireplaceQu'] == 'Po' ]['SalePrice'].plot(kind='kde', ax=ax, label='Po')
dataCat[dataCat['FireplaceQu'].isnull()]['SalePrice'].plot(kind='kde', ax=ax, label='NAN')

plt.legend()
plt.show()

# %%
dataHP['FireplaceQu'].fillna('Missing', inplace=True)

# %%
plt.figure(figsize=(6, 3))
dataHP['FireplaceQu'].value_counts(normalize=True).sort_values(ascending=False).plot.bar()
plt.xlabel("Categoria")
plt.ylabel("Cantidad de Casas")
plt.show()

# %% [markdown]
# ## 2. Codificación de Variables Categóricas

# %%
dataCE = dataHP[['Neighborhood', 'Exterior1st', 'Exterior2nd', 'SalePrice']]
dataCE.shape
# Out:
# (1460, 4)

# %%
dataCE['Neighborhood'].unique()
# Out:
# array(['CollgCr', 'Veenker', 'Crawfor', 'NoRidge', 'Mitchel', 'Somerst',
#        'NWAmes', 'OldTown', 'BrkSide', 'Sawyer', 'NridgHt', 'NAmes',
#        'SawyerW', 'IDOTRR', 'MeadowV', 'Edwards', 'Timber', 'Gilbert',
#        'StoneBr', 'ClearCr', 'NPkVill', 'Blmngtn', 'BrDale', 'SWISU',
#        'Blueste'], dtype=object)

# %%
pd.get_dummies(dataCE, drop_first=True)
# Out:
#       SalePrice  Neighborhood_Blueste  Neighborhood_BrDale  \
# 0        208500                 False                False
# 1        181500                 False                False
# 2        223500                 False                False
# 3        140000                 False                False
# 4        250000                 False                False
# ...         ...                   ...                  ...
# 1455     175000                 False                False
# 1456     210000                 False                False
# 1457     266500                 False                False
# 1458     142125                 False                False
# 1459     147500                 False                False
#
#       Neighborhood_BrkSide  Neighborhood_ClearCr  Neighborhood_CollgCr  \
# 0                    False                 False                  True
# 1                    False                 False                 False
# 2                    False                 False                  True
# 3                    False                 False                 False
# 4                    False                 False                 False
# ...                    ...                   ...                   ...
# 1455                 False                 False                 False
# 1456                 False                 False                 False
# 1457                 False                 False                 False
# 1458                 False                 False                 False
# 1459                 False                 False                 False
#
#       Neighborhood_Crawfor  Neighborhood_Edwards  Neighborhood_Gilbert  \
# 0                    False                 False                 False
# 1                    False                 False                 False
# 2                    False                 False                 False
# 3                     True                 False                 False
# 4                    False                 False                 False
# ...                    ...                   ...                   ...
# 1455                 False                 False                  True
# 1456                 False                 False                 False
# 1457                  True                 False                 False
# 1458                 False                 False                 False
# 1459                 False                  True                 False
#
#       Neighborhood_IDOTRR  ...  Exterior2nd_HdBoard  Exterior2nd_ImStucc  \
# 0                   False  ...                False                False
# 1                   False  ...                False                False
# 2                   False  ...                False                False
# 3                   False  ...                False                False
# 4                   False  ...                False                False
# ...                   ...  ...                  ...                  ...
# 1455                False  ...                False                False
# 1456                False  ...                False                False
# 1457                False  ...                False                False
# 1458                False  ...                False                False
# 1459                False  ...                 True                False
#
#       Exterior2nd_MetalSd  Exterior2nd_Other  Exterior2nd_Plywood  \
# 0                   False              False                False
# 1                    True              False                False
# 2                   False              False                False
# 3                   False              False                False
# 4                   False              False                False
# ...                   ...                ...                  ...
# 1455                False              False                False
# 1456                False              False                 True
# 1457                False              False                False
# 1458                 True              False                False
# 1459                False              False                False
#
#       Exterior2nd_Stone  Exterior2nd_Stucco  Exterior2nd_VinylSd  \
# 0                 False               False                 True
# 1                 False               False                False
# 2                 False               False                 True
# 3                 False               False                False
# 4                 False               False                 True
# ...                 ...                 ...                  ...
# 1455              False               False                 True
# 1456              False               False                False
# 1457              False               False                False
# 1458              False               False                False
# 1459              False               False                False
#
#       Exterior2nd_Wd Sdng  Exterior2nd_Wd Shng
# 0                   False                False
# 1                   False                False
# 2                   False                False
# 3                   False                 True
# 4                   False                False
# ...                   ...                  ...
# 1455                False                False
# 1456                False                False
# 1457                False                False
# 1458                False                False
# 1459                False                False
#
# [1460 rows x 54 columns]

# %%
dataCE['Neighborhood'].value_counts(ascending=False)
# Out:
# Neighborhood
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# Timber      38
# IDOTRR      37
# ClearCr     28
# StoneBr     25
# SWISU       25
# MeadowV     17
# Blmngtn     17
# BrDale      16
# Veenker     11
# NPkVill      9
# Blueste      2
# Name: count, dtype: int64

# %%
import seaborn as sns

plt.subplots(figsize=(18, 6))

sales = dataCE['SalePrice']
nbh = dataCE['Neighborhood']
sns.boxplot(x=nbh, y=sales)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### Codificación para variable Neighborhood en Fequency Encoding

# %%
nbh_freq_dict = dataCE['Neighborhood'].value_counts(ascending=False).to_dict()

# %%
dataCE.head()
# Out:
#   Neighborhood Exterior1st Exterior2nd  SalePrice
# 0      CollgCr     VinylSd     VinylSd     208500
# 1      Veenker     MetalSd     MetalSd     181500
# 2      CollgCr     VinylSd     VinylSd     223500
# 3      Crawfor     Wd Sdng     Wd Shng     140000
# 4      NoRidge     VinylSd     VinylSd     250000

# %%
dataCE['Neighborhood'] = dataCE['Neighborhood'].map(nbh_freq_dict)
# Out:
# /var/folders/52/w3v5_lr57951tzsccv4jk6fw0000gn/T/ipykernel_61940/3831809119.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCE['Neighborhood'] = dataCE['Neighborhood'].map(nbh_freq_dict)

# %%
dataCE.head()
# Out:
#    Neighborhood Exterior1st Exterior2nd  SalePrice
# 0           150     VinylSd     VinylSd     208500
# 1            11     MetalSd     MetalSd     181500
# 2           150     VinylSd     VinylSd     223500
# 3            51     Wd Sdng     Wd Shng     140000
# 4            41     VinylSd     VinylSd     250000

# %%
def frequency_encoding_procedure(data_serie):
       freq_dict = data_serie.value_counts(ascending=False).to_dict()
       return data_serie.map(freq_dict)

# %%
for col in dataCE.columns:
       dataCE[col] = frequency_encoding_procedure(dataCE[col])
# Out:
# /var/folders/52/w3v5_lr57951tzsccv4jk6fw0000gn/T/ipykernel_61940/858439986.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCE[col] = frequency_encoding_procedure(dataCE[col])
# /var/folders/52/w3v5_lr57951tzsccv4jk6fw0000gn/T/ipykernel_61940/858439986.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCE[col] = frequency_encoding_procedure(dataCE[col])
# /var/folders/52/w3v5_lr57951tzsccv4jk6fw0000gn/T/ipykernel_61940/858439986.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataCE[col] = frequency_encoding_procedure(dataCE[col])

# %%
dataCE.head()
# Out:
#    Neighborhood  Exterior1st  Exterior2nd  SalePrice
# 0           150          515          504          1
# 1            11          220          214          1
# 2           150          515          504          2
# 3            51          206           38         20
# 4            41          515          504          8

# %% [markdown]
# ### Tratamiento de Outliers

# %%
import seaborn as sns
import scipy.stats as stats

# %%
def get_variables_scale(dataset):
       categoricas = [col for col in dataset.columns if dataset[col].dtype == 'object']
       continuas = [col for col in dataset.columns if dataset[col].dtype in ['float64', 'int64'] and len(dataset[col].unique()) > 30]
       discretas = [col for col in dataset.columns if dataset[col].dtype in ['float64', 'int64'] and len(dataset[col].unique()) <= 30]

       return categoricas, continuas, discretas

# %%
cat, cont, disct = get_variables_scale(dataHP)

# %%
def plot_outliers_analysis(dataset, col):
       plt.figure(figsize=(10, 2))
       print(col)
       plt.subplot(131)
       dataset[col].hist(bins=50, density=True, color='red')
       plt.title("Densisda - Histogrma")
       plt.subplot(132)
       stats.probplot(dataset[col], dist="norm", plot=plt)
       plt.title("QQ-Plot") 
       plt.subplot(133)
       sns.boxplot(y=dataset[col])
       plt.title("Boxplot")
       plt.show()

# %%
for col in cont:
       plot_outliers_analysis(dataHP, col)
# Out:
# Id
# LotFrontage
# LotArea
# YearBuilt
# YearRemodAdd
# MasVnrArea
# BsmtFinSF1
# BsmtFinSF2
# BsmtUnfSF
# TotalBsmtSF
# 1stFlrSF
# 2ndFlrSF
# GrLivArea
# GarageYrBlt
# GarageArea
# WoodDeckSF
# OpenPorchSF
# EnclosedPorch
# ScreenPorch
# SalePrice

# %%
def get_outliers_limits(dataset, col):
       IQR = dataHP[col].quantile(0.75) - dataHP[col].quantile(0.25)
       LI = dataHP[col].quantile(0.25) - (1.5*IQR)
       LS = dataHP[col].quantile(0.75) + (1.5*IQR)

       return LI, LS

# %%
get_outliers_limits(dataHP, '1stFlrSF')
# Out:
# (118.125, 2155.125)

# %%
plot_outliers_analysis(dataHP, '1stFlrSF')
# Out:
# 1stFlrSF

# %%
LI, LS = get_outliers_limits(dataHP, '1stFlrSF')

dataHP['1stFlrSF_capp'] = np.where(dataHP['1stFlrSF'] > LS, LS, 
                 np.where(dataHP['1stFlrSF'] < LI, LI, 
                 dataHP['1stFlrSF']))

# %%
plot_outliers_analysis(dataHP, '1stFlrSF_capp')
# Out:
# 1stFlrSF_capp

# %%
LI, LS = get_outliers_limits(dataHP, '1stFlrSF_capp')
LI, LS
# Out:
# (118.125, 2155.125)

# %% [markdown]
# ### Transformación de Variables

# %%
import scipy.stats as stats

# %%
continuas = [col for col in dataHP.columns if(dataHP[col].dtype in ['float64', 'int64']) and (len(dataHP[col].unique()) > 30)]
continuas

# %%
discretas = [col for col in dataHP.columns if(dataHP[col].dtype in ['float64', 'int64']) and (len(dataHP[col].unique()) <= 30)]
discretas

# %%
def plot_density_qq(df, variable):

       plt.figure(figsize = (7, 3))

       plt.subplot(121)
       df[variable].hist(bins=30)
       plt.title(variable)

       plt.subplot(122)
       stats.probplot(df[variable], dist='norm', plot=plt)
       plt.show()

# %%
col = "GrLivArea"
plot_density_qq(dataHP, col)

# %%
dataHP[col].describe()
# Out:
# count    1460.000000
# mean     1515.463699
# std       525.480383
# min       334.000000
# 25%      1129.500000
# 50%      1464.000000
# 75%      1776.750000
# max      5642.000000
# Name: GrLivArea, dtype: float64

# %% [markdown]
# #### Transformación Logarítmica

# %%
dataHP[col + '_log'] = np.log(dataHP[col])
plot_density_qq(dataHP, col + '_log')

# %% [markdown]
# #### Transformación Inversa

# %%
dataHP[col + '_inv'] = 1/(dataHP[col])
plot_density_qq(dataHP, col + '_inv')

# %% [markdown]
# ### Transforamción Polinomial de Orden 2

# %%
dataHP[col + '_cuad'] = (dataHP[col])**2
plot_density_qq(dataHP, col + '_cuad')

# %%
dataHP[col + '_BC'], lmbd  = stats.boxcox(dataHP[col])
lmbd = str(round(lmbd, 4))
print(lmbd)
plot_density_qq(dataHP, col + '_BC')
# Out:
# 0.0063

# %%
dataHP[col + '_YJ'], lmbd  = stats.yeojohnson(dataHP[col])
lmbd = str(round(lmbd, 4))
print(lmbd)
plot_density_qq(dataHP, col + '_YJ')
# Out:
# 0.0055

# %% [markdown]
# ### Feature Scaling

# %%
dataHP.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... YrSold SaleType SaleCondition SalePrice  \
# 0         Lvl    AllPub  ...   2008       WD        Normal    208500
# 1         Lvl    AllPub  ...   2007       WD        Normal    181500
# 2         Lvl    AllPub  ...   2008       WD        Normal    223500
# 3         Lvl    AllPub  ...   2006       WD       Abnorml    140000
# 4         Lvl    AllPub  ...   2008       WD        Normal    250000
#
#   1stFlrSF_capp GrLivArea_log GrLivArea_inv  GrLivArea_cuad  GrLivArea_BC  \
# 0         856.0      7.444249      0.000585         2924100      7.621721
# 1        1262.0      7.140453      0.000792         1592644      7.303631
# 2         920.0      7.487734      0.000560         3189796      7.667302
# 3         961.0      7.448334      0.000582         2948089      7.626003
# 4        1145.0      7.695303      0.000455         4831204      7.885049
#
#    GrLivArea_YJ
# 0      7.600485
# 1      7.284380
# 2      7.645781
# 3      7.604740
# 4      7.862156
#
# [5 rows x 87 columns]

# %%
dataHP.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#             MiscVal       MoSold       YrSold      SalePrice  1stFlrSF_capp  \
# count   1460.000000  1460.000000  1460.000000    1460.000000    1460.000000
# mean      43.489041     6.321918  2007.815753  180921.195890    1157.018151
# std      496.123024     2.703626     1.328095   79442.502883     362.583002
# min        0.000000     1.000000  2006.000000   34900.000000     334.000000
# 25%        0.000000     5.000000  2007.000000  129975.000000     882.000000
# 50%        0.000000     6.000000  2008.000000  163000.000000    1087.000000
# 75%        0.000000     8.000000  2009.000000  214000.000000    1391.250000
# max    15500.000000    12.000000  2010.000000  755000.000000    2155.125000
#
#        GrLivArea_log  GrLivArea_inv  GrLivArea_cuad  GrLivArea_BC  \
# count    1460.000000    1460.000000    1.460000e+03   1460.000000
# mean        7.267774       0.000738    2.572571e+06      7.437236
# std         0.333550       0.000256    2.064173e+06      0.349190
# min         5.811141       0.000177    1.115560e+05      5.918914
# 25%         7.029530       0.000563    1.275771e+06      7.187641
# 50%         7.288928       0.000683    2.143296e+06      7.459016
# 75%         7.482541       0.000885    3.156842e+06      7.661859
# max         8.637994       0.002994    3.183216e+07      8.877554
#
#        GrLivArea_YJ
# count   1460.000000
# mean       7.417149
# std        0.346996
# min        5.908776
# 25%        7.169113
# 50%        7.438796
# 75%        7.640371
# max        8.848187
#
# [8 rows x 44 columns]

# %%
fig = plt.figure(figsize=(6, 3))
ax = fig.add_subplot(111)
dataHP['LotFrontage'].plot(kind='kde', ax=ax, label='LotFrontage')
dataHP['LotArea'].plot(kind='kde', ax=ax, label='LotArea')
plt.title("LotFrontage vrs LotArea")

plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(6, 3))
ax = fig.add_subplot(111)
plt.scatter(x=dataHP['LotArea'], y=dataHP['LotFrontage'])
plt.title("LotFrontage vrs LotArea")
plt.xlim((0, 300000))
plt.ylim((0, 300000))

plt.show()

# %% [markdown]
# #### Scaling para LotFrontage

# %%
min_lf = dataHP['LotFrontage'].min()
max_lf = dataHP['LotFrontage'].max()

dataHP['LotFrontage_minMaxScaled'] = (dataHP['LotFrontage'] - min_lf)/(max_lf - min_lf)

# %%
min_lf = dataHP['LotArea'].min()
max_lf = dataHP['LotArea'].max()

dataHP['LotArea_minMaxScaled'] = (dataHP['LotArea'] - min_lf)/(max_lf - min_lf)

# %%
fig = plt.figure(figsize=(6, 3))
ax = fig.add_subplot(111)
dataHP['LotFrontage_minMaxScaled'].plot(kind='kde', ax=ax, label='LotFrontage')
dataHP['LotArea_minMaxScaled'].plot(kind='kde', ax=ax, label='LotArea')
plt.title("LotFrontage vrs LotArea Escalado")

plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(6, 3))
ax = fig.add_subplot(111)
plt.scatter(x=dataHP['LotArea_minMaxScaled'], y=dataHP['LotFrontage_minMaxScaled'])
plt.title("LotFrontage vrs LotArea")

plt.show()

# %% [markdown]
# ### Proceos de Ingeniería de Características - Feature Engineering Pipeline

# %% [markdown]
# 0. Determinar escalas de las variables:
#  * Numéricas:
#    * Continuas.
#    * Discretas.
#    * Categóricas.
#
# 1. Imputación de Variables:
#  Se debe hacer para completar el dataset en los casos que es posible.
#     * Mixtos - Complete Case Analysis (CCA) - Faltantes <= 5%
#     * Numéricas - Faltantes <= 5%:
#        * Media.
#        * Mediana.
#        * Probabilistica - Faltantes <= 20% - Hacer análisis.
#        * Eliminar columna para casos con faltantes > 20%
#
# 2. Codificación de Variables Categóricas:
#  * Se debe hacer para transformar variables que tiene strings en numeros, por que los algoritmos de ML solo entiende numeros.
#     * One Hot Encoding - Aplica a 10 o menos clases.
#     * Codificación por Frecuencia (recomendado).
#     * Target - Label Encoding.
#
# 3. Tratamiento de Outliers (solo variables continuas):
# * Se debe hacer para evitar modelos con sesgos fuertes generados por minimizar el error con los outliers.
#    * Detacción basada en el IQR, usar 1.5*IQR como factor
#    * Capping
#
# 4. Transformación de Variables:
#  * Se debe hacer por que los modelos asumen que el comportamiento de las variables tiene una distribuación normal. Se debe buscar la mejor (aproximadamente normal).
#     * Logarítmica o exponencial.
#     * polinomial.
#     * inversa/reciproca.
#     * Box-Cox
#     * Yeo-Johnson
#
# 5. Feature Scaling:
#  * Se debe hacer por que las escalas muy distintas generan modelos con poca estructura y malos para predecir.
#     * MinMaxScaler (0, 1).
#     * StandarSacler (-4 , 4).
